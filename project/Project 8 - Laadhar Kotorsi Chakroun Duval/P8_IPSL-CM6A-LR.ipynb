# %% [markdown]
# #AMO
# **The Atlantic Multidecadal Oscillation (AMO)** index is a measure of the **variability in sea surface temperatures** (SSTs) in the **North Atlantic Ocean**. Our way to calculate AMO and the AMO index associated is to detrend the spatially averaged timeseries (give us AMO index timeserie) and then to do a linear regression (give us AMO oscillation over Atlantic).

# %% [markdown]
# ## **Imports**

# %%
# first we have to install some libraries in Colab
# !pip install zarr
# !pip install gcsfs
# !pip uninstall -y shapely 
# !pip install shapely==1.8.5 --no-binary shapely
# !pip install cartopy==0.18
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting zarr
#   Downloading zarr-2.13.6-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.0/193.0 KB 5.9 MB/s eta 0:00:00
# Collecting numcodecs>=0.10.0
#   Downloading numcodecs-0.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from zarr) (1.21.6)
# Collecting fasteners
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Collecting asciitree
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from numcodecs>=0.10.0->zarr) (0.4)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5050 sha256=d0ce944d8c23b683e384607d5e2607a22a9d60b43afe42d63e0701ddd4cf9ed4
#   Stored in directory: /root/.cache/pip/wheels/a3/d7/75/19cd0d2a893cad4bb0b2b16dd572ad2916d19c0d5ee9612511
# Successfully built asciitree
# Installing collected packages: asciitree, numcodecs, fasteners, zarr
# Successfully installed asciitree-0.3.3 fasteners-0.18 numcodecs-0.11.0 zarr-2.13.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gcsfs
#   Downloading gcsfs-2022.11.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from gcsfs) (2.25.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from gcsfs) (3.8.3)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.8/dist-packages (from gcsfs) (0.4.6)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.8/dist-packages (from gcsfs) (2.7.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.8/dist-packages (from gcsfs) (2.16.0)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.8/dist-packages (from gcsfs) (4.4.2)
# Requirement already satisfied: fsspec==2022.11.0 in /usr/local/lib/python3.8/dist-packages (from gcsfs) (2022.11.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs) (5.2.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib->gcsfs) (1.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage->gcsfs) (2.11.0)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage->gcsfs) (2.4.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage->gcsfs) (2.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->gcsfs) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->gcsfs) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->gcsfs) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->gcsfs) (2.10)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs) (3.19.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)
# Installing collected packages: gcsfs
# Successfully installed gcsfs-2022.11.0
# Found existing installation: shapely 2.0.0
# Uninstalling shapely-2.0.0:
#   Successfully uninstalled shapely-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shapely==1.8.5
#   Downloading Shapely-1.8.5.tar.gz (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.7/200.7 KB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for shapely==1.8.5 from https://files.pythonhosted.org/packages/21/d0/82ea9573c9ba8e7a5709ee08681249ad25411382f6440f548981286f3b74/Shapely-1.8.5.tar.gz#sha256=e82b6d60ecfb124120c88fe106a478596bbeab142116d7e7f64a364dac902a92.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'wheel'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: shapely
#   Building wheel for shapely (pyproject.toml) ... done
#   Created wheel for shapely: filename=Shapely-1.8.5-cp38-cp38-linux_x86_64.whl size=971095 sha256=b3e63c3c84090cdd96e548676e85c0838821074f185f0e5420b0bd0f97f53d2c
#   Stored in directory: /root/.cache/pip/wheels/a4/2d/72/220175deeb59b36459e7255fb29a8f1b4b948d9e42f83acf1d
# Successfully built shapely
# Installing collected packages: shapely
# Successfully installed shapely-1.8.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cartopy==0.18
#   Downloading Cartopy-0.18.0.tar.gz (14.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 82.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.8/dist-packages (from cartopy==0.18) (1.21.6)
# Requirement already satisfied: shapely>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from cartopy==0.18) (1.8.5)
# Collecting pyshp>=1.1.4
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from cartopy==0.18) (1.15.0)
# Requirement already satisfied: setuptools>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from cartopy==0.18) (57.4.0)
# Building wheels for collected packages: cartopy
#   Building wheel for cartopy (setup.py) ... done
#   Created wheel for cartopy: filename=Cartopy-0.18.0-cp38-cp38-linux_x86_64.whl size=15706266 sha256=d7ca244be648183256972e2e2017d6276a2f58b4ce5736134f5d1dce55fb07db
#   Stored in directory: /root/.cache/pip/wheels/7c/3c/68/ed800c08e3e6579b632fdd26becee97c5c5474625f6c97eca6
# Successfully built cartopy
# Installing collected packages: pyshp, cartopy
# Successfully installed cartopy-0.18.0 pyshp-2.3.1

# %%
# set up our libraries
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import dask.array as da
import zarr
import numpy as np
from matplotlib.axes import Axes
import gcsfs

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.axes import Axes
from cartopy.mpl.geoaxes import GeoAxes
# notebook display options
xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## **Browse CMIP6 catalog`**

# %%
df_full = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df_full.sample(5)
# Out:
#         activity_id institution_id           source_id   experiment_id  \
# 496505  ScenarioMIP           MOHC         UKESM1-0-LL          ssp126
# 374367         DCPP           NCAR  CESM1-1-CAM5-CMIP5  dcppA-hindcast
# 347082         DCPP           NCAR  CESM1-1-CAM5-CMIP5  dcppA-hindcast
# 290214         DCPP            NCC             NorCPM1  dcppA-hindcast
# 458234        PAMIP            NCC          NorESM2-LM    pa-futArcSIC
#
#         member_id table_id variable_id grid_label  \
# 496505   r7i1p1f2     Amon        hurs         gn
# 374367  r39i1p1f1     Omon         tos         gn
# 347082   r4i1p1f1     Amon         clt         gn
# 290214   r6i1p1f1     Amon         tas         gn
# 458234  r27i1p1f1     Amon         psl         gn
#
#                                                    zstore  dcpp_init_year  \
# 496505  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...             NaN
# 374367  gs://cmip6/DCPP/NCAR/CESM1-1-CAM5-CMIP5/dcppA-...          1996.0
# 347082  gs://cmip6/DCPP/NCAR/CESM1-1-CAM5-CMIP5/dcppA-...          1965.0
# 290214  gs://cmip6/DCPP/NCC/NorCPM1/dcppA-hindcast/s19...          1998.0
# 458234  gs://cmip6/CMIP6/PAMIP/NCC/NorESM2-LM/pa-futAr...             NaN
#
#          version
# 496505  20201015
# 374367  20191016
# 347082  20191007
# 290214  20190914
# 458234  20200702

# %% [markdown]
# # **First experiment: historical for model IPSL-CM6A-LR**

# %%
df_tos = df_full.query("activity_id == 'CMIP' & institution_id == 'IPSL' & source_id=='IPSL-CM6A-LR' & experiment_id=='historical' & member_id=='r1i1p1f1' & table_id == 'Omon' & variable_id == 'tos'")
print(df_tos.shape)
df_tos
# Out:
# (1, 11)
#       activity_id institution_id     source_id experiment_id member_id  \
# 28719        CMIP           IPSL  IPSL-CM6A-LR    historical  r1i1p1f1
#
#       table_id variable_id grid_label  \
# 28719     Omon         tos         gn
#
#                                                   zstore  dcpp_init_year  \
# 28719  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
#
#         version
# 28719  20180803

# %%
# this only needs to be created once
gcs = gcsfs.GCSFileSystem(token='anon')

# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_tos.zstore.values[-1]
print(zstore)
# create a mutable-mapping-style interface to the store
mapper = gcs.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
ds
# Out:
# gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Omon/tos/gn/v20180803/
# <xarray.Dataset>
# Dimensions:         (y: 332, x: 362, nvertex: 4, time: 1980, axis_nbounds: 2)
# Coordinates:
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * time            (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T...
#     time_bounds     (time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1980, 2), meta=np.ndarray>
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables:
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     tos             (time, y, x) float32 dask.array<chunksize=(252, 332, 362), meta=np.ndarray>
# Attributes: (12/54)
#     CMIP6_CV_version:       cv=6.2.3.5-2-g63b123e
#     Conventions:            CF-1.7 CMIP-6.2
#     EXPID:                  historical
#     NCO:                    "4.6.0"
#     activity_id:            CMIP
#     branch_method:          standard
#     ...                     ...
#     tracking_id:            hdl:21.14100/01f4d96a-9054-4974-b8dd-4f91e73989d2
#     variable_id:            tos
#     variant_label:          r1i1p1f1
#     status:                 2019-11-10;created;by nhn2@columbia.edu
#     netcdf_tracking_ids:    hdl:21.14100/01f4d96a-9054-4974-b8dd-4f91e73989d2
#     version_id:             v20180803

# %%
#Select the Atlantic Area
start_yr=1856
final_yr=2014
start_date="1856-01-01"
final_date="2013-12-31"
ds1 = ds.sel(x=slice(200,280)).sel(y=slice(210,280)).sel(time=slice(start_date,final_date))

# %%
#Calculate the spatially averaged timeseries to have values per year
sst_clim = []
for i in range(start_yr,final_yr):
  sst_clim.append(ds1.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time").mean("x").mean("y"))

# %%
sst_clim= [np.float32(val) for val in sst_clim]

# %%
# We detrend the spatial averaged timeseries
from sklearn.linear_model import LinearRegression
X1= range(final_yr-start_yr)
alpha1 = LinearRegression().fit(np.reshape(X1,(-1, 1)), sst_clim)

# %%
plt.plot(sst_clim)
plt.plot(alpha1.predict(np.reshape(X1,(-1, 1))))
plt.title("Spatial averaged timeseries and its trend")
# Out:
# Text(0.5, 1.0, 'Spatial averaged timeseries and its trend')

# %%
sst_clim_detrend= sst_clim-alpha1.predict(np.reshape(X1,(-1, 1)))

# %%
plt.plot(sst_clim_detrend)
plt.title("Approximated AMO")
# Out:
# Text(0.5, 1.0, 'Approximated AMO')

# %%
# Program to calculate moving average
window_size = 5
i = 0
# Initialize an empty list to store moving averages
moving_averages = []
# Loop through the array to consider every window of size 5
while i < len(sst_clim_detrend) - window_size + 1:
	
	# Store elements from i to i+window_size
	# in list to get the current window
	window = sst_clim_detrend[i : i + window_size]

	# Calculate the average of current window
	window_average = round(sum(window) / window_size, 2)
	
	# Store the average of current
	# window in moving average list
	moving_averages.append(window_average)
	
	# Shift window to right by one position
	i += 1
yrs=np.arange(start_yr,final_yr- window_size + 1,1) #problème on a que 154 valeurs avec moving average....
plt.plot(yrs,moving_averages,color='black')
plt.title("AMO Index approximated for historical (model IPSL-CM6A-LR)")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 < np.array(moving_averages)),
        color= "orange")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 > np.array(moving_averages)),
        color= "blue")

# %%
# Transformation of sst to have mean per year in any location in the Atlantic
sst = []
for i in range(start_yr,final_yr):
  sst.append(ds1.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time"))

# %%
from sklearn.linear_model import LinearRegression
X=sst_clim_detrend
y=np.reshape(sst,(final_yr-start_yr,-1))
# Check for NaN values in the data
if np.isnan(y).any():
    print("Data contains NaN values.")
    y = np.nan_to_num(y)
    print("NaN values replaced with finite numbers.")

alpha = LinearRegression().fit(np.reshape(X,(-1, 1)), y)
# Out:
# Data contains NaN values.
# NaN values replaced with finite numbers.

# %%
coeff=alpha.coef_
coeff=coeff.reshape(70,-1)

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(10,10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add coastlines and states
ax.add_feature(cfeature.STATES)

# Plot the AMO index
im = ax.imshow(coeff, origin='lower', cmap='RdBu_r')

# Add colorbar
cbar = plt.colorbar(im,ax=ax)

# Add title
plt.title('Observed AMO SST Pattern for historical (model IPSL-CM6A-LR)')

# Display the plot
plt.show()

# %% [markdown]
# # **Second experiment: piControl for model IPSL-CM6A-LR**

# %%
df_tos = df_full.query("activity_id == 'CMIP' & institution_id == 'IPSL' & source_id=='IPSL-CM6A-LR' & experiment_id=='piControl' & member_id=='r1i1p1f1' & table_id == 'Omon' & variable_id == 'tos'")
print(df_tos.shape)
df_tos
# Out:
# (1, 11)
#        activity_id institution_id     source_id experiment_id member_id  \
# 429164        CMIP           IPSL  IPSL-CM6A-LR     piControl  r1i1p1f1
#
#        table_id variable_id grid_label  \
# 429164     Omon         tos         gn
#
#                                                    zstore  dcpp_init_year  \
# 429164  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/piCont...             NaN
#
#          version
# 429164  20200326

# %%
# this only needs to be created once
gcs = gcsfs.GCSFileSystem(token='anon')

# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_tos.zstore.values[-1]
print(zstore)
# create a mutable-mapping-style interface to the store
mapper = gcs.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
ds
# Out:
# gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/piControl/r1i1p1f1/Omon/tos/gn/v20200326/
# /usr/local/lib/python3.8/dist-packages/xarray/coding/times.py:699: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.8/dist-packages/xarray/coding/times.py:699: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.8/dist-packages/xarray/core/indexing.py:524: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)
# <xarray.Dataset>
# Dimensions:         (y: 332, x: 362, nvertex: 4, time: 14400, axis_nbounds: 2)
# Coordinates:
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * time            (time) object 1850-01-16 12:00:00 ... 3049-12-16 12:00:00
#     time_bounds     (time, axis_nbounds) object dask.array<chunksize=(14400, 2), meta=np.ndarray>
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables:
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     tos             (time, y, x) float32 dask.array<chunksize=(252, 332, 362), meta=np.ndarray>
# Attributes: (12/54)
#     CMIP6_CV_version:       cv=6.2.3.5-2-g63b123e
#     Conventions:            CF-1.7 CMIP-6.2
#     EXPID:                  piControl
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     ...                     ...
#     tracking_id:            hdl:21.14100/640fb3e1-ddac-4da8-ac5a-339f83df1540...
#     variable_id:            tos
#     variant_info:           . Information provided by this attribute may in s...
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/640fb3e1-ddac-4da8-ac5a-339f83df1540...
#     version_id:             v20200326

# %%
#Select the Atlantic Area
start_yr=1850
final_yr=2100
start_date="1850-01-01"
final_date="2100-12-31"
ds1 = ds.sel(x=slice(200,280)).sel(y=slice(210,280)).sel(time=slice(start_date,final_date))

# %%
#Calculate the spatially averaged timeseries to have values per year
sst_clim = []
for i in range(start_yr,final_yr):
  sst_clim.append(ds1.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time").mean("x").mean("y"))

# %%
sst_clim= [np.float32(val) for val in sst_clim]

# %%
# We detrend the spatial averaged timeseries
from sklearn.linear_model import LinearRegression
X1= range(final_yr-start_yr)
alpha1 = LinearRegression().fit(np.reshape(X1,(-1, 1)), sst_clim)

# %%
plt.plot(sst_clim)
plt.plot(alpha1.predict(np.reshape(X1,(-1, 1))))
plt.title("Spatial averaged timeseries and its trend")
# Out:
# Text(0.5, 1.0, 'Spatial averaged timeseries and its trend')

# %%
sst_clim_detrend= sst_clim-alpha1.predict(np.reshape(X1,(-1, 1)))

# %%
plt.plot(sst_clim_detrend)
plt.title("Approximated AMO")
# Out:
# Text(0.5, 1.0, 'Approximated AMO')

# %%
# Program to calculate moving average
window_size = 5
i = 0
# Initialize an empty list to store moving averages
moving_averages = []
# Loop through the array to consider every window of size 5
while i < len(sst_clim_detrend) - window_size + 1:
	
	# Store elements from i to i+window_size
	# in list to get the current window
	window = sst_clim_detrend[i : i + window_size]

	# Calculate the average of current window
	window_average = round(sum(window) / window_size, 2)
	
	# Store the average of current
	# window in moving average list
	moving_averages.append(window_average)
	
	# Shift window to right by one position
	i += 1
yrs=np.arange(start_yr,final_yr- window_size + 1,1) #problème on a que 154 valeurs avec moving average....
plt.plot(yrs,moving_averages)
plt.title("AMO Index approximated")
plt.grid()

# %%
yrs=np.arange(start_yr,final_yr- window_size + 1,1) #problème on a que 154 valeurs avec moving average....
plt.plot(yrs,moving_averages,color='black')
plt.title("AMO Index approximated for piControl")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 < np.array(moving_averages)),
        color= "orange")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 > np.array(moving_averages)),
        color= "blue")

# %%
# Transformation of sst to have mean per year in any location in the Atlantic
sst = []
for i in range(start_yr,final_yr):
  sst.append(ds1.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time"))

# %%
from sklearn.linear_model import LinearRegression
X=sst_clim_detrend
y=np.reshape(sst,(final_yr-start_yr,-1))
# Check for NaN values in the data
if np.isnan(y).any():
    print("Data contains NaN values.")
    y = np.nan_to_num(y)
    print("NaN values replaced with finite numbers.")

alpha = LinearRegression().fit(np.reshape(X,(-1, 1)), y)
# Out:
# Data contains NaN values.
# NaN values replaced with finite numbers.

# %%
coeff=alpha.coef_
coeff=coeff.reshape(70,-1)

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(10,10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add coastlines and states
ax.add_feature(cfeature.STATES)

# Plot the AMO index
im = ax.imshow(coeff, origin='lower', cmap='RdBu_r')

# Add colorbar
cbar = plt.colorbar(im,ax=ax)

# Add title
plt.title('Observed AMO SST Pattern for piControl')

# Display the plot
plt.show()

# %% [markdown]
# # **Third experiment: 1pctCO2 for model IPSL-CM6A-LR**

# %%
one_pct_df = df_full.query("activity_id == 'CMIP' & institution_id == 'IPSL' & source_id=='IPSL-CM6A-LR' & experiment_id=='1pctCO2' & member_id=='r1i1p1f1' & table_id == 'Omon' & variable_id == 'tos'")
one_pct_df
# Out:
# (1, 11)
#        activity_id institution_id     source_id experiment_id member_id  \
# 429164        CMIP           IPSL  IPSL-CM6A-LR     piControl  r1i1p1f1
#
#        table_id variable_id grid_label  \
# 429164     Omon         tos         gn
#
#                                                    zstore  dcpp_init_year  \
# 429164  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/piCont...             NaN
#
#          version
# 429164  20200326

# %%
# this only needs to be created once
gcs = gcsfs.GCSFileSystem(token='anon')

# get the path to a specific zarr store (the first one from the dataframe above)
zstore = one_pct_df.zstore.values[-1]
print(zstore)
# create a mutable-mapping-style interface to the store
one_pct_mapper = gcs.get_mapper(zstore)

# open it using xarray and zarr
one_pct_data = xr.open_zarr(one_pct_mapper, consolidated=True)
one_pct_data
# Out:
# gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/piControl/r1i1p1f1/Omon/tos/gn/v20200326/
# /usr/local/lib/python3.8/dist-packages/xarray/coding/times.py:699: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.8/dist-packages/xarray/coding/times.py:699: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.8/dist-packages/xarray/core/indexing.py:524: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)
# <xarray.Dataset>
# Dimensions:         (y: 332, x: 362, nvertex: 4, time: 14400, axis_nbounds: 2)
# Coordinates:
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#   * time            (time) object 1850-01-16 12:00:00 ... 3049-12-16 12:00:00
#     time_bounds     (time, axis_nbounds) object dask.array<chunksize=(14400, 2), meta=np.ndarray>
# Dimensions without coordinates: y, x, nvertex, axis_nbounds
# Data variables:
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     tos             (time, y, x) float32 dask.array<chunksize=(252, 332, 362), meta=np.ndarray>
# Attributes: (12/54)
#     CMIP6_CV_version:       cv=6.2.3.5-2-g63b123e
#     Conventions:            CF-1.7 CMIP-6.2
#     EXPID:                  piControl
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     ...                     ...
#     tracking_id:            hdl:21.14100/640fb3e1-ddac-4da8-ac5a-339f83df1540...
#     variable_id:            tos
#     variant_info:           . Information provided by this attribute may in s...
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/640fb3e1-ddac-4da8-ac5a-339f83df1540...
#     version_id:             v20200326

# %%
#Select the Atlantic Area
start_yr=1850
final_yr=2000
start_date="1850-01-16"
final_date="1999-12-1"
one_pct_atl = one_pct_data.sel(x=slice(200,280)).sel(y=slice(210,280)).sel(time=slice(start_date,final_date))

# %%
#Calculate the spatially averaged timeseries to have values per year
one_pct_sst_avg = []
for i in range(start_yr,final_yr):
  one_pct_sst_avg.append(one_pct_atl.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time").mean("x").mean("y"))

# %%
one_pct_sst_avg= [np.float32(val) for val in one_pct_sst_avg]

# %%
# We detrend the spatial averaged timeseries
from sklearn.linear_model import LinearRegression
X1= range(final_yr-start_yr)
alpha1 = LinearRegression().fit(np.reshape(X1,(-1, 1)), one_pct_sst_avg)

# %%
plt.plot(one_pct_sst_avg)
plt.plot(alpha1.predict(np.reshape(X1,(-1, 1))))
plt.title("Spatial averaged timeseries and its trend")
# Out:
# Text(0.5, 1.0, 'Spatial averaged timeseries and its trend')

# %%
one_pct_sst_detrend= one_pct_sst_avg-alpha1.predict(np.reshape(X1,(-1, 1)))

# %%
plt.plot(one_pct_sst_detrend)
plt.title("Approximated AMO for experiment '1pctCO2'")
# Out:
# Text(0.5, 1.0, 'Approximated AMO')

# %%
# Program to calculate moving average
window_size = 5
i = 0
# Initialize an empty list to store moving averages
moving_averages = []
# Loop through the array to consider every window of size 5
while i < len(one_pct_sst_detrend) - window_size + 1:
	
	# Store elements from i to i+window_size
	# in list to get the current window
	window = one_pct_sst_detrend[i : i + window_size]

	# Calculate the average of current window
	window_average = round(sum(window) / window_size, 2)
	
	# Store the average of current
	# window in moving average list
	moving_averages.append(window_average)
	
	# Shift window to right by one position
	i += 1
yrs=np.arange(start_yr,final_yr- window_size + 1,1) #problème on a que 154 valeurs avec moving average....
plt.plot(yrs,moving_averages,color='black')
plt.title("AMO Index approximated for 1pctCO2")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 < np.array(moving_averages)),
        color= "orange")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 > np.array(moving_averages)),
        color= "blue")
plt.xlabel("Years")

# %%
yrs=np.arange(start_yr,final_yr- window_size + 1,1) #problème on a que 154 valeurs avec moving average....
plt.plot(yrs,moving_averages,color='black')
plt.title("AMO Index approximated for 1pctCO2")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 < np.array(moving_averages)),
        color= "orange")
plt.fill_between(
        x= yrs, 
        y1= moving_averages, 
        where= (0 > np.array(moving_averages)),
        color= "blue")

# %%
# Transformation of sst to have mean per year in any location in the Atlantic
sst_one_pct = []
for i in range(start_yr,final_yr):
  sst_one_pct.append(one_pct_atl.sel(time=slice(str(i)+"-01-01", str(i)+"-12-31")).tos.mean("time"))

# %%
from sklearn.linear_model import LinearRegression
X=one_pct_sst_detrend
y=np.reshape(sst_one_pct,(final_yr-start_yr,-1))
# Check for NaN values in the data
if np.isnan(y).any():
    print("Data contains NaN values.")
    y = np.nan_to_num(y)
    print("NaN values replaced with finite numbers.")

alpha = LinearRegression().fit(np.reshape(X,(-1, 1)), y)
# Out:
# Data contains NaN values.
# NaN values replaced with finite numbers.

# %%
coeff=alpha.coef_
coeff=coeff.reshape(70,-1)

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(10,10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add coastlines and states
ax.add_feature(cfeature.STATES)

# Plot the AMO index
im = ax.imshow(coeff, origin='lower', cmap='RdBu_r')

# Add colorbar
# cbar = plt.colorbar(im,ax=ax)

# Add title
plt.title('Observed AMO SST Pattern for 1pctCO2')

# Display the plot
plt.show()
